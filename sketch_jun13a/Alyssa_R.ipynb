# %%
# 将bed文件转为csv后读取
# 查看前6行，观察是否导入正确
data_bed <- read.csv("gencode.v28.annotation.csv")
head(data_bed)
# Out:
#   X One               Two                                symbol
# 1 0 ENSG00000223972.5 transcribed_unprocessed_pseudogene DDX11L1
# 2 1 ENSG00000227232.5 unprocessed_pseudogene             WASH7P
# 3 2 ENSG00000278267.1 miRNA                              MIR6859-1
# 4 3 ENSG00000243485.5 lincRNA                            RP11-34P13.3
# 5 4 ENSG00000284332.1 miRNA                              MIR1302-2
# 6 5 ENSG00000237613.2 lincRNA                            FAM138A

# %%
data_txt <- read.csv("K6_0.8_true.sig.genes.csv", header=T,check.names=FALSE)
head(data_txt)
# Out:
#   symbol   cluster
# 1 TSPAN6   1
# 2 DPM1     2
# 3 C1orf112 3
# 4 CFH      2
# 5 FUCA2    1
# 6 STPG1    3
